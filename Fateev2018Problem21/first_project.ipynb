6  5   aug  fri  91.0  166.9  752.6   7.1  18.2  62   5.4   0.0   0.43
# 511  8  6   aug  sun  81.6   56.7  665.6   1.9  27.8  35   2.7   0.0   0.00
# 512  4  3   aug  sun  81.6   56.7  665.6   1.9  27.8  32   2.7   0.0   6.44
# 513  2  4   aug  sun  81.6   56.7  665.6   1.9  21.9  71   5.8   0.0  54.29
# 514  7  4   aug  sun  81.6   56.7  665.6   1.9  21.2  70   6.7   0.0  11.16
# 515  1  4   aug  sat  94.4  146.0  614.7  11.3  25.6  42   4.0   0.0   0.00
# 516  6  3   nov  tue  79.5    3.0  106.7   1.1  11.8  31   4.5   0.0   0.00
#
# [517 rows x 13 columns]

# %%
data.sort_values(by=['area'])[-25:]
# Out:
#      X  Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain     area
# 504  4  3   aug  wed  94.5  139.4  689.1  20.0  28.9  29   4.9   0.0    49.59
# 395  4  5   feb  sun  85.0    9.0   56.9   3.5  10.1  62   1.8   0.0    51.78
# 513  2  4   aug  sun  81.6   56.7  665.6   1.9  21.9  71   5.8   0.0    54.29
# 337  6  3   sep  mon  91.6  108.4  764.0   6.2  23.0  34   2.2   0.0    56.04
# 227  8  6   aug  sat  92.2   81.8  480.8  11.9  20.1  34   4.5   0.0    58.30
# 469  6  3   apr  sun  91.0   14.6   25.6  12.3  13.7  33   9.4   0.0    61.13
# 228  4  6   sep  sun  93.5  149.3  728.6   8.1  28.3  26   3.1   0.0    64.10
# 473  9  4   jun  sat  90.5   61.1  252.6   9.4  24.5  50   3.1   0.0    70.32
# 392  1  3   sep  sun  91.0  276.3  825.1   7.1  21.9  43   4.0   0.0    70.76
# 229  8  6   aug  sat  92.2   81.8  480.8  11.9  16.4  43   4.0   0.0    71.30
# 457  1  4   aug  wed  91.7  191.4  635.9   7.8  19.9  50   4.0   0.0    82.75
# 293  7  6   jul  tue  93.1  180.4  430.8  11.0  26.9  28   5.4   0.0    86.45
# 230  4  4   sep  wed  92.9  133.3  699.6   9.2  26.4  21   4.5   0.0    88.49
# 231  1  5   sep  sun  93.5  149.3  728.6   8.1  27.8  27   3.1   0.0    95.18
# 232  6  4   sep  tue  91.0  129.5  692.6   7.0  18.7  43   2.7   0.0   103.39
# 233  9  4   sep  tue  84.4   73.4  671.9   3.2  24.3  36   3.1   0.0   105.66
# 234  4  5   sep  sat  92.5  121.1  674.4   8.6  17.7  25   3.1   0.0   154.88
# 377  2  2   aug  sat  93.7  231.1  715.1   8.4  21.9  42   2.2   0.0   174.63
# 420  8  8   aug  wed  91.7  191.4  635.9   7.8  26.2  36   4.5   0.0   185.76
# 235  8  6   aug  sun  91.4  142.4  601.4  10.6  19.6  41   5.8   0.0   196.48
# 236  2  2   sep  sat  92.5  121.1  674.4   8.6  18.2  46   1.8   0.0   200.94
# 237  1  2   sep  tue  91.0  129.5  692.6   7.0  18.8  40   2.2   0.0   212.88
# 479  7  4   jul  mon  89.2  103.9  431.6   6.4  22.6  57   4.9   0.0   278.53
# 415  8  6   aug  thu  94.8  222.4  698.6  13.9  27.5  27   4.9   0.0   746.28
# 238  6  5   sep  sat  92.5  121.1  674.4   8.6  25.1  27   4.0   0.0  1090.84

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 517 entries, 0 to 516
# Data columns (total 13 columns):
# X        517 non-null int64
# Y        517 non-null int64
# month    517 non-null object
# day      517 non-null object
# FFMC     517 non-null float64
# DMC      517 non-null float64
# DC       517 non-null float64
# ISI      517 non-null float64
# temp     517 non-null float64
# RH       517 non-null int64
# wind     517 non-null float64
# rain     517 non-null float64
# area     517 non-null float64
# dtypes: float64(8), int64(3), object(2)
# memory usage: 52.6+ KB

# %%
data.columns
# Out:
# Index(['X', 'Y', 'month', 'day', 'FFMC', 'DMC', 'DC', 'ISI', 'temp', 'RH',
#        'wind', 'rain', 'area'],
#       dtype='object')

# %%
def get_data(df):
    # month_and_days_in_number
    month_w = ['jan', 'feb', 'dec', 'mar', 'apr', 'oct', 'nov', 'may']
    #month_sp = ['jun', 'apr', 'may']
    month_sm = ['sep', 'jul', 'aug', 'jun']
    #month_au = ['jan', 'oct', 'nov']
    #set_per = [month_w, month_sm]
    
    for month in month_sm:
        df['month'][df.month == month] = 1
    for month in month_w:
        df['month'][df.month == month] = 0 
    days_work = ['mon', 'tue', 'wed', 'thu', 'fri']
    days_hol = ['sat', 'sun']
    for day in days_hol:
        df['day'][df.day == day] = 1 
    for day in days_work:
        df['day'][df.day == day] = 0
    return df

# %%
X_data = data.iloc[:,0:-1]
X_data = get_data(X_data)
X_data = X_data.rename(columns={'month' : 'per'})
#X_data = pd.get_dummies(X_data, columns=['per'])
#X_data = X_data.drop(columns=['FFMC', 'DMC', 'DC', 'ISI', 'temp', 'RH'])
X_data
# Out:
# /home/anton/.local/lib/python3.5/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# /home/anton/.local/lib/python3.5/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# /home/anton/.local/lib/python3.5/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /home/anton/.local/lib/python3.5/site-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#      X  Y per day  FFMC    DMC     DC   ISI  temp  RH  wind  rain
# 0    7  5   0   0  86.2   26.2   94.3   5.1   8.2  51   6.7   0.0
# 1    7  4   0   0  90.6   35.4  669.1   6.7  18.0  33   0.9   0.0
# 2    7  4   0   1  90.6   43.7  686.9   6.7  14.6  33   1.3   0.0
# 3    8  6   0   0  91.7   33.3   77.5   9.0   8.3  97   4.0   0.2
# 4    8  6   0   1  89.3   51.3  102.2   9.6  11.4  99   1.8   0.0
# 5    8  6   1   1  92.3   85.3  488.0  14.7  22.2  29   5.4   0.0
# 6    8  6   1   0  92.3   88.9  495.6   8.5  24.1  27   3.1   0.0
# 7    8  6   1   0  91.5  145.4  608.2  10.7   8.0  86   2.2   0.0
# 8    8  6   1   0  91.0  129.5  692.6   7.0  13.1  63   5.4   0.0
# 9    7  5   1   1  92.5   88.0  698.6   7.1  22.8  40   4.0   0.0
# 10   7  5   1   1  92.5   88.0  698.6   7.1  17.8  51   7.2   0.0
# 11   7  5   1   1  92.8   73.2  713.0  22.6  19.3  38   4.0   0.0
# 12   6  5   1   0  63.5   70.8  665.3   0.8  17.0  72   6.7   0.0
# 13   6  5   1   0  90.9  126.5  686.5   7.0  21.3  42   2.2   0.0
# 14   6  5   1   0  92.9  133.3  699.6   9.2  26.4  21   4.5   0.0
# 15   6  5   1   0  93.3  141.2  713.9  13.9  22.9  44   5.4   0.0
# 16   5  5   0   1  91.7   35.8   80.8   7.8  15.1  27   5.4   0.0
# 17   8  5   0   0  84.9   32.8  664.2   3.0  16.7  47   4.9   0.0
# 18   6  4   0   0  89.2   27.9   70.8   6.3  15.9  35   4.0   0.0
# 19   6  4   0   1  86.3   27.4   97.1   5.1   9.3  44   4.5   0.0
# 20   6  4   1   0  91.0  129.5  692.6   7.0  18.3  40   2.7   0.0
# 21   5  4   1   0  91.8   78.5  724.3   9.2  19.1  38   2.7   0.0
# 22   7  4   1   1  94.3   96.3  200.0  56.1  21.0  44   4.5   0.0
# 23   7  4   1   1  90.2  110.9  537.4   6.2  19.5  43   5.8   0.0
# 24   7  4   1   1  93.5  139.4  594.2  20.3  23.7  32   5.8   0.0
# 25   7  4   1   1  91.4  142.4  601.4  10.6  16.3  60   5.4   0.0
# 26   7  4   1   0  92.4  117.9  668.0  12.2  19.0  34   5.8   0.0
# 27   7  4   1   0  90.9  126.5  686.5   7.0  19.4  48   1.3   0.0
# 28   6  3   1   1  93.4  145.4  721.4   8.1  30.2  24   2.7   0.0
# 29   6  3   1   1  93.5  149.3  728.6   8.1  22.8  39   3.6   0.0
# ..  .. ..  ..  ..   ...    ...    ...   ...   ...  ..   ...   ...
# 487  5  4   1   0  95.1  141.3  605.8  17.7  26.4  34   3.6   0.0
# 488  4  4   1   0  95.1  141.3  605.8  17.7  19.4  71   7.6   0.0
# 489  4  4   1   0  95.1  141.3  605.8  17.7  20.6  58   1.3   0.0
# 490  4  4   1   0  95.1  141.3  605.8  17.7  28.7  33   4.0   0.0
# 491  4  4   1   0  95.8  152.0  624.1  13.8  32.4  21   4.5   0.0
# 492  1  3   1   0  95.9  158.0  633.6  11.3  32.4  27   2.2   0.0
# 493  1  3   1   0  95.9  158.0  633.6  11.3  27.5  29   4.5   0.0
# 494  6  6   1   1  96.0  164.0  643.0  14.0  30.8  30   4.9   0.0
# 495  6  6   1   0  96.2  175.5  661.8  16.8  23.9  42   2.2   0.0
# 496  4  5   1   0  96.2  175.5  661.8  16.8  32.6  26   3.1   0.0
# 497  3  4   1   0  96.1  181.1  671.2  14.3  32.3  27   2.2   0.0
# 498  6  5   1   0  96.1  181.1  671.2  14.3  33.3  26   2.7   0.0
# 499  7  5   1   0  96.1  181.1  671.2  14.3  27.3  63   4.9   6.4
# 500  8  6   1   0  96.1  181.1  671.2  14.3  21.6  65   4.9   0.8
# 501  7  5   1   0  96.1  181.1  671.2  14.3  21.6  65   4.9   0.8
# 502  4  4   1   0  96.1  181.1  671.2  14.3  20.7  69   4.9   0.4
# 503  2  4   1   0  94.5  139.4  689.1  20.0  29.2  30   4.9   0.0
# 504  4  3   1   0  94.5  139.4  689.1  20.0  28.9  29   4.9   0.0
# 505  1  2   1   0  91.0  163.2  744.4  10.1  26.7  35   1.8   0.0
# 506  1  2   1   0  91.0  166.9  752.6   7.1  18.5  73   8.5   0.0
# 507  2  4   1   0  91.0  166.9  752.6   7.1  25.9  41   3.6   0.0
# 508  1  2   1   0  91.0  166.9  752.6   7.1  25.9  41   3.6   0.0
# 509  5  4   1   0  91.0  166.9  752.6   7.1  21.1  71   7.6   1.4
# 510  6  5   1   0  91.0  166.9  752.6   7.1  18.2  62   5.4   0.0
# 511  8  6   1   1  81.6   56.7  665.6   1.9  27.8  35   2.7   0.0
# 512  4  3   1   1  81.6   56.7  665.6   1.9  27.8  32   2.7   0.0
# 513  2  4   1   1  81.6   56.7  665.6   1.9  21.9  71   5.8   0.0
# 514  7  4   1   1  81.6   56.7  665.6   1.9  21.2  70   6.7   0.0
# 515  1  4   1   1  94.4  146.0  614.7  11.3  25.6  42   4.0   0.0
# 516  6  3   0   0  79.5    3.0  106.7   1.1  11.8  31   4.5   0.0
#
# [517 rows x 12 columns]

# %%
X_data = X_data.astype('float64')
from sklearn.preprocessing import scale
from sklearn.model_selection import train_test_split
X_data_s = scale(X_data)
Y_data = np.array(data['area'], dtype='float64')
Y_data = np.log(1 + Y_data)

X_data_train, X_data_test, Y_data_train, Y_data_test = train_test_split(X_data, Y_data, test_size=0.25)
X_data_train_s, X_data_test_s, Y_data_train_s, Y_data_test_s = train_test_split(X_data, Y_data, test_size=0.25)

# %%
from sklearn import linear_model
reg_s = linear_model.Ridge(alpha = .5)
reg_s.fit(X_data_train_s,Y_data_train) 
w1 = reg_s.coef_
reg = linear_model.Ridge(alpha = .5)
reg.fit(X_data_train,Y_data_train) 
w2 = reg.coef_

# %% [markdown]
# ## With standardization

# %% [markdown]
# ## Train

# %%
x = np.dot(X_data_train_s,w1)
y = Y_data_train_s
p1 = np.poly1d(np.polyfit(x,y,1))
plt.scatter(x,y,color='r')
plt.plot(x,p1(x),'g')
plt.xlim(0.5, 3)
plt.show()

# %% [markdown]
# ## Test

# %%
x = np.dot(X_data_test_s,w1)
y = Y_data_test_s
p1 = np.poly1d(np.polyfit(x,y,1))
plt.scatter(x,y,color='r')
plt.plot(x,p1(x),'g')
plt.xlim(1, 2)
plt.show()

# %%
plt.plot(X_data.columns,w1)
plt.show()

# %% [markdown]
# ### Error

# %%
Q_train = np.linalg.norm(Y_data_train_s - np.dot(X_data_train_s, w1), ord=2)
Q_test = np.linalg.norm(Y_data_test_s - np.dot(X_data_test_s, w1), ord=2)
print(Q_train, Q_test)
# Out:
# 27.65785653098468 16.936922899293748

# %% [markdown]
# ## Without standardization

# %% [markdown]
# ## Train

# %%
x = np.dot(X_data_train,w2)
y = Y_data_train
p1 = np.poly1d(np.polyfit(x,y,1))
plt.scatter(x,y,color='r')
plt.plot(x,p1(x),'g')
plt.xlim(-1, 2)
plt.show()

# %% [markdown]
# ## Test

# %%
x = np.dot(X_data_test,w2)
y = Y_data_test
p1 = np.poly1d(np.polyfit(x,y,1))
plt.scatter(x,y,color='r')
plt.plot(x,p1(x),'g')
plt.xlim(0, 2)
plt.show()

# %%
plt.plot(X_data.columns, w2)
plt.show()

# %% [markdown]
# ### Error

# %%
Q_train = np.linalg.norm(Y_data_train - np.dot(X_data_train, w1), ord=2)
Q_test = np.linalg.norm(Y_data_test - np.dot(X_data_test, w1), ord=2)
print(Q_train, Q_test)
# Out:
# 27.470862563809384 17.238564185727558
